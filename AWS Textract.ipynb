# %% [markdown]
# ## Task1:Computer Vision and Internet of Things

# %% [markdown]
# ### OCR(Optical Character Recognition)

# %% [markdown]
# ### Character Detector that which extracts printed or handwritten text from images

# %% [markdown]
# ### Approach:Amazon Textract,one of the best OCR technique available is used here

# %%
from textract import amazon_textract

# %% [markdown]
# #### Input image

# %% [markdown]
# ![answers.png](attachment:answers.png)

# %% [markdown]
# #### Initialize access key,region and secret access key and connect to Amazon Textract

# %%
accesskey="Enter Access key"
secretaccesskey="Enter Secret Access Key"
region="Enter Region"
at1=amazon_textract(accesskey,secretaccesskey,region)

# %% [markdown]
# #### Read the input file and analyze the image and convert it to text.

# %%
filename="answers.png"
content=at1.read_file(filename)
at1.analyze_document(content)
# Out:
# o
# You are
# Viewing 006 Arulmozhi's applications
# -
# o
# x
# Current Affairs Answers August 12, 2021
# 1.Emma Mckeon
# 2. Sudha Murthy
# 3. Rajasthan
# 4. Mohammad Mokhber
# 5. Kolkata
# 6. Tata Consultancy Services
# 7. Nagaland
# 8. Neeraj Chopra
# 9. August 10
# 10. Al-Mohed Al-Hindi 2021
# 9:47 AM
# .
# Type here to search
# C
# 3
# Il.
# 8/13/2021
